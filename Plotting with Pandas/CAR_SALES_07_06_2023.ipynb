# %% [markdown]
# # Loading the Libraries

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('./Car_sales (2).csv')
data.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %% [markdown]
# #### Renaming the columns

# %%
data.rename(columns={'__year_resale_value':'year_resale_value'}, inplace=True)
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  year_resale_value Vehicle_type  \
# 0          Acura  Integra              16.919             16.360    Passenger
# 1          Acura       TL              39.384             19.875    Passenger
# 2          Acura       CL              14.114             18.225    Passenger
# 3          Acura       RL               8.588             29.725    Passenger
# 4           Audi       A4              20.397             22.255    Passenger
# ..           ...      ...                 ...                ...          ...
# 152        Volvo      V40               3.545                NaN    Passenger
# 153        Volvo      S70              15.245                NaN    Passenger
# 154        Volvo      V70              17.531                NaN    Passenger
# 155        Volvo      C70               3.493                NaN    Passenger
# 156        Volvo      S80              18.969                NaN    Passenger
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Manufacturer        157 non-null    object
#  1   Model               157 non-null    object
#  2   Sales_in_thousands  157 non-null    float64
#  3   year_resale_value   121 non-null    float64
#  4   Vehicle_type        157 non-null    object
#  5   Price_in_thousands  155 non-null    float64
#  6   Engine_size         156 non-null    float64
#  7   Horsepower          156 non-null    float64
#  8   Wheelbase           156 non-null    float64
#  9   Width               156 non-null    float64
#  10  Length              156 non-null    float64
#  11  Curb_weight         155 non-null    float64
#  12  Fuel_capacity       156 non-null    float64
#  13  Fuel_efficiency     154 non-null    float64
#  14  Latest_Launch       157 non-null    object
# ...

# %% [markdown]
# #### Descriptive statistics

# %%
data.describe()
# Out:
#        Sales_in_thousands  year_resale_value  Price_in_thousands  Engine_size  \
# count          157.000000         121.000000          155.000000   156.000000
# mean            52.998076          18.072975           27.390755     3.060897
# std             68.029422          11.453384           14.351653     1.044653
# min              0.110000           5.160000            9.235000     1.000000
# 25%             14.114000          11.260000           18.017500     2.300000
# 50%             29.450000          14.180000           22.799000     3.000000
# 75%             67.956000          19.875000           31.947500     3.575000
# max            540.561000          67.550000           85.500000     8.000000
#
#        Horsepower   Wheelbase       Width      Length  Curb_weight  \
# count  156.000000  156.000000  156.000000  156.000000   155.000000
# mean   185.948718  107.487179   71.150000  187.343590     3.378026
# ...

# %%
data.isnull().mean()*100
# Out:
# Manufacturer           0.000000
# Model                  0.000000
# Sales_in_thousands     0.000000
# year_resale_value     22.929936
# Vehicle_type           0.000000
# Price_in_thousands     1.273885
# Engine_size            0.636943
# Horsepower             0.636943
# Wheelbase              0.636943
# Width                  0.636943
# Length                 0.636943
# Curb_weight            1.273885
# Fuel_capacity          0.636943
# Fuel_efficiency        1.910828
# Latest_Launch          0.000000
# Power_perf_factor      1.273885
# dtype: float64

# %% [markdown]
# Dropping na values

# %%
data.dropna(inplace=True)
data.isnull().mean()*100
# Out:
# Manufacturer          0.0
# Model                 0.0
# Sales_in_thousands    0.0
# year_resale_value     0.0
# Vehicle_type          0.0
# Price_in_thousands    0.0
# Engine_size           0.0
# Horsepower            0.0
# Wheelbase             0.0
# Width                 0.0
# Length                0.0
# Curb_weight           0.0
# Fuel_capacity         0.0
# Fuel_efficiency       0.0
# Latest_Launch         0.0
# Power_perf_factor     0.0
# dtype: float64

# %%
data.drop_duplicates(inplace=True)

# %%
data.Manufacturer.value_counts()
# Out:
# Ford          10
# Dodge          9
# Chevrolet      8
# Toyota         8
# Mitsubishi     7
# Mercury        6
# Chrysler       5
# Honda          5
# Pontiac        5
# Nissan         5
# Volkswagen     5
# Mercedes-B     4
# Oldsmobile     4
# Buick          4
# Saturn         3
# Porsche        3
# Plymouth       3
# Acura          3
# Audi           3
# Jeep           3
# Hyundai        3
# Cadillac       3
# Lexus          3
# Lincoln        2
# BMW            2
# Infiniti       1
# Name: Manufacturer, dtype: int64

# %%
data.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', 'year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %% [markdown]
# # Plots on numerical values

# %% [markdown]
# Histogram

# %%
data.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919             16.360    Passenger
# 1        Acura       TL              39.384             19.875    Passenger
# 3        Acura       RL               8.588             29.725    Passenger
# 4         Audi       A4              20.397             22.255    Passenger
# 5         Audi       A6              18.780             23.555    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
# 5               33.95          2.8       200.0      108.7   76.1   192.0
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %%
data.Width.plot.hist(cmap='autumn');

# %%
data.Horsepower.plot.hist(figsize=(6,3),cmap='rainbow');

# %% [markdown]
# Box plot

# %%
data.Length.plot.box(figsize=(5,4),cmap='Pastel2');

# %%
data.Horsepower.plot.box();

# %%
data.Sales_in_thousands.plot.box(figsize=(5,4),cmap="viridis");

# %% [markdown]
# subplots

# %%
data.plot.box(figsize=(22,4),subplots=True);

# %%
data.plot.hist(figsize=(8,14),subplots=True);

# %% [markdown]
# Line chart

# %%
data.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919             16.360    Passenger
# 1        Acura       TL              39.384             19.875    Passenger
# 3        Acura       RL               8.588             29.725    Passenger
# 4         Audi       A4              20.397             22.255    Passenger
# 5         Audi       A6              18.780             23.555    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
# 5               33.95          2.8       200.0      108.7   76.1   192.0
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %%
data.sort_values(by='Price_in_thousands')[:20].plot.line('Price_in_thousands','Engine_size',figsize=(6,4),cmap='viridis',legend=True);

# %%
data.plot.line(figsize=(15,8),subplots=True);

# %%
data.sort_values(by='Price_in_thousands')[:5].plot.line('Latest_Launch','Price_in_thousands', figsize=(12,3));

# %%
data.sort_values("year_resale_value").plot.line('year_resale_value', 'Price_in_thousands',figsize=(6,3),cmap='inferno');

# %% [markdown]
# Bar plot

# %%
data.Manufacturer.value_counts().plot.bar(figsize=(6,2),cmap='turbo_r');

# %%
data.sort_values(by='Price_in_thousands')[:20].plot.bar('Manufacturer','Price_in_thousands',figsize=(6,3),cmap='Pastel2');

# %% [markdown]
# Area chart

# %%
data.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919             16.360    Passenger
# 1        Acura       TL              39.384             19.875    Passenger
# 3        Acura       RL               8.588             29.725    Passenger
# 4         Audi       A4              20.397             22.255    Passenger
# 5         Audi       A6              18.780             23.555    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
# 5               33.95          2.8       200.0      108.7   76.1   192.0
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %%
data.plot.area('Model','Horsepower',figsize=(15,5),cmap='rainbow');

# %%
data.plot.area('Manufacturer','Sales_in_thousands',figsize=(8,3),cmap='gist_earth');

# %% [markdown]
# Horizontal bar chart

# %%
data.sort_values(by='Engine_size')[:8].plot.barh('Model','Engine_size');

# %%
data.Engine_size[:8].plot.barh('Manufacturer','Engine_size');

# %%
data.sort_values(by='Price_in_thousands')[:5].plot.scatter('Latest_Launch','Price_in_thousands', figsize=(12,3));

# %%
data.sort_values(by='Width')[:12].plot.scatter('Fuel_capacity','Width',figsize=(5,5));

# %%
data.Manufacturer.value_counts()[:5].plot.pie(autopct='%1.2f%%');

# %%
data.sort_values(by='Engine_size',ascending=False)[:10].Engine_size.plot.pie(legend=True,autopct='%1.0f%%');

# %%
data.Vehicle_type.value_counts().plot.pie(legend=True,autopct='%1.0f%%');

# %% [markdown]
# kde plot

# %%
data.plot.kde(figsize=(10,3.8),cmap='rainbow');

# %%
data.plot.kde(figsize=(12,10),subplots=True,cmap='rainbow');
